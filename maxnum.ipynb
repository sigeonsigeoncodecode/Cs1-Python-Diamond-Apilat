# %% [markdown]
# <a href="https://colab.research.google.com/github/sigeonsigeoncodecode/Cs1-Python-Diamond-Apilat/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Ask the user to input 3 numbers
num1 = float(input("Enter the 1st number: "))
num2 = float(input("Enter the 2nd number: "))
num3 = float(input("Enter the 3rd number: "))

# 2. Compare the numbers to find the biggest one
if (num1 >= num2) and (num1 >= num3):
    biggest = num1
elif (num2 >= num1) and (num2 >= num3):
    biggest = num2
else:
    biggest = num3

# 3. Print out the biggest number
print (f"The biggest number is: {biggest}")
# Out:
# Enter the 1st number: 59
# Enter the 2nd number: 82
# Enter the 3rd number: 71
# The biggest number is: 82.0
